# %% [markdown]
# ## Schema translation
#
# When we replicate topics from a source cluster using the DefaultReplicationPolicty in MM2, topic names have the `source.` prefix.
#
# We can only deserialize these topics if the schemas are registered under a subject name that follows the topic name because we use the `topic.name.strategy.topic` topic name strategy.
#
# This notebook iterates over schemas in the target cluster (replicated from the source cluster) and register them under a new subject name that includes the `source.` prefix.

# %% [markdown]
# ### Check schema registry mode
# Schema registry mode must be READWRITE to run this notebook.

# %%
import httpx

schema_registry_url = "http://sasquatch-source-schema-registry.sasquatch:8081"

async with httpx.AsyncClient() as client:

    response = await client.get(f"{schema_registry_url}/mode")

    if response.status_code == 200:  # Successful response
        print(response.text)
    else:
        print(f"Request failed with status code: {response.status_code}")
# Out:
# {"mode":"READWRITE"}

# %% [markdown]
# ### Fetch subjects
# Make a list of subjects

# %%
import httpx

schema_registry_url = "http://sasquatch-source-schema-registry.sasquatch:8081"

async with httpx.AsyncClient() as client:

    response = await client.get(f"{schema_registry_url}/subjects")

    if response.status_code == 200:  # Successful response
        subjects = [subject for subject in response.json() if subject.startswith("lsst.sal")]
    else:
        print(f"Request failed with status code: {response.status_code}")

print(f"Found {len(subjects)} subjects.")
# Out:
# Found 2396 subjects.

# %% [markdown]
# ### Register schema under new subject name

# %%
import httpx

schema_registry_url = "http://sasquatch-source-schema-registry.sasquatch:8081"
headers = {"Content-Type": "application/vnd.schemaregistry.v1+json"}

async with httpx.AsyncClient() as client:
    for subject in subjects:
        # Get the latest version of the schema
        url = f"{schema_registry_url}/subjects/{subject}/versions/latest"

        response = await client.get(url)

        if response.status_code == 200:
            data = response.json()
        else:
            print(f"Failed to retrieve schema for {subject}. Status code: {response.status_code}")
            break

        schema = {'schema': data['schema']}

        # Check if a schema has already been registered under the new subject.
        new_subject = f"source.{subject}"

        url = f"{schema_registry_url}/subjects/{new_subject}"
        response = await client.post(url, headers=headers, json=schema)

        if response.status_code == 200:
            print(f"Schema already registered under {new_subject}.")
        else:
            # Register schema under new subject name
            url = f"{schema_registry_url}/subjects/{new_subject}/versions"
            response = await client.post(url, headers=headers, json=schema)

            if response.status_code == 200:
                print(f"Registered schema under new subject {new_subject} with {response.text}")
            else:
                print(f"Failed to register schema under subject {subject}. Status code: {response.status_code}")
                break
# Out:
# Registered schema under new subject source.lsst.sal.ATAOS.ackcmd-value with {"id":6480}
# Registered schema under new subject source.lsst.sal.ATAOS.command_applyCorrection-value with {"id":6484}
# Registered schema under new subject source.lsst.sal.ATAOS.command_applyFocusOffset-value with {"id":6487}
# Registered schema under new subject source.lsst.sal.ATAOS.command_disable-value with {"id":6482}
# Registered schema under new subject source.lsst.sal.ATAOS.command_disableCorrection-value with {"id":6481}
# Registered schema under new subject source.lsst.sal.ATAOS.command_enable-value with {"id":6483}
# Registered schema under new subject source.lsst.sal.ATAOS.command_enableCorrection-value with {"id":6491}
# Registered schema under new subject source.lsst.sal.ATAOS.command_exitControl-value with {"id":6485}
# Registered schema under new subject source.lsst.sal.ATAOS.command_offset-value with {"id":6490}
# Registered schema under new subject source.lsst.sal.ATAOS.command_resetOffset-value with {"id":6486}
# Registered schema under new subject source.lsst.sal.ATAOS.command_setAuthList-value with {"id":6493}
# Registered schema under new subject source.lsst.sal.ATAOS.command_setCorrectionModelOffsets-value with {"id":6499}
# Registered schema under new subject source.lsst.sal.ATAOS.command_setLogLevel-value with {"id":6488}
# Registered schema under new subject source.lsst.sal.ATAOS.command_setWavelength-value with {"id":6489}
# Registered schema under new subject source.lsst.sal.ATAOS.command_standby-value with {"id":6492}
# Registered schema under new subject source.lsst.sal.ATAOS.command_start-value with {"id":6495}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_atspectrographCorrectionCompleted-value with {"id":6494}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_atspectrographCorrectionStarted-value with {"id":6497}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_authList-value with {"id":6498}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_configurationApplied-value with {"id":6496}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_configurationsAvailable-value with {"id":6615}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_correctionEnabled-value with {"id":6616}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_correctionOffsets-value with {"id":6617}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_detailedState-value with {"id":6625}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_errorCode-value with {"id":6623}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_focusCorrectionCompleted-value with {"id":6624}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_focusCorrectionStarted-value with {"id":6626}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_focusOffsetSummary-value with {"id":6627}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_heartbeat-value with {"id":6628}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_hexapodCorrectionCompleted-value with {"id":6629}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_hexapodCorrectionStarted-value with {"id":6630}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_logLevel-value with {"id":6631}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_logMessage-value with {"id":6632}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_m1CorrectionCompleted-value with {"id":6636}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_m1CorrectionStarted-value with {"id":6663}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_m2CorrectionCompleted-value with {"id":6664}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_m2CorrectionStarted-value with {"id":6667}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_pointingOffsetSummary-value with {"id":6666}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_simulationMode-value with {"id":6665}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_softwareVersions-value with {"id":6669}
# Registered schema under new subject source.lsst.sal.ATAOS.logevent_summaryState-value with {"id":6779}
# Registered schema under new subject source.lsst.sal.ATAOS.timestamp-value with {"id":6785}
# Schema already registered under source.lsst.sal.ATArchiver.ackcmd-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_disable-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_enable-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_exitControl-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_resetFromFault-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_setAuthList-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_setLogLevel-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_standby-value.
# Schema already registered under source.lsst.sal.ATArchiver.command_start-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_authList-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_errorCode-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_heartbeat-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_imageInOODS-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_imageRetrievalForArchiving-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_logLevel-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_logMessage-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_simulationMode-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_softwareVersions-value.
# Schema already registered under source.lsst.sal.ATArchiver.logevent_summaryState-value.
# Registered schema under new subject source.lsst.sal.ATCamera.ackcmd-value with {"id":5817}
# Registered schema under new subject source.lsst.sal.ATCamera.bonn_shutter_Device-value with {"id":6050}
# Registered schema under new subject source.lsst.sal.ATCamera.command_alert-value with {"id":5812}
# Registered schema under new subject source.lsst.sal.ATCamera.command_clear-value with {"id":5813}
# Registered schema under new subject source.lsst.sal.ATCamera.command_disable-value with {"id":5804}
# Registered schema under new subject source.lsst.sal.ATCamera.command_disableCalibration-value with {"id":5806}
# Registered schema under new subject source.lsst.sal.ATCamera.command_discardRows-value with {"id":5807}
# Registered schema under new subject source.lsst.sal.ATCamera.command_enable-value with {"id":5798}
# Registered schema under new subject source.lsst.sal.ATCamera.command_enableCalibration-value with {"id":5814}
# Registered schema under new subject source.lsst.sal.ATCamera.command_endImage-value with {"id":5801}
# Registered schema under new subject source.lsst.sal.ATCamera.command_enterControl-value with {"id":5808}
# Registered schema under new subject source.lsst.sal.ATCamera.command_exitControl-value with {"id":5805}
# Registered schema under new subject source.lsst.sal.ATCamera.command_initGuiders-value with {"id":5816}
# Registered schema under new subject source.lsst.sal.ATCamera.command_initImage-value with {"id":5815}
# Registered schema under new subject source.lsst.sal.ATCamera.command_play-value with {"id":5809}
# Registered schema under new subject source.lsst.sal.ATCamera.command_playlist-value with {"id":5799}
# Registered schema under new subject source.lsst.sal.ATCamera.command_setAuthList-value with {"id":5803}
# Registered schema under new subject source.lsst.sal.ATCamera.command_setLogLevel-value with {"id":5802}
# Registered schema under new subject source.lsst.sal.ATCamera.command_standby-value with {"id":5811}
# Registered schema under new subject source.lsst.sal.ATCamera.command_start-value with {"id":5810}
# Registered schema under new subject source.lsst.sal.ATCamera.command_startImage-value with {"id":5800}
# Registered schema under new subject source.lsst.sal.ATCamera.command_stop-value with {"id":5818}
# Registered schema under new subject source.lsst.sal.ATCamera.command_takeImages-value with {"id":5819}
# Registered schema under new subject source.lsst.sal.ATCamera.daq_monitor_Store-value with {"id":6053}
# Registered schema under new subject source.lsst.sal.ATCamera.focal_plane_Ccd-value with {"id":6054}
# Registered schema under new subject source.lsst.sal.ATCamera.focal_plane_Reb-value with {"id":6059}
# Registered schema under new subject source.lsst.sal.ATCamera.focal_plane_RebTotalPower-value with {"id":6055}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_alertRaised-value with {"id":5820}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_CryoCon_DeviceConfiguration-value with {"id":5822}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_CryoCon_DevicesConfiguration-value with {"id":5821}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_PeriodicTasks_GeneralConfiguration-value with {"id":5823}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_PeriodicTasks_timersConfiguration-value with {"id":5824}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_Pfeiffer_DeviceConfiguration-value with {"id":5825}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_Pfeiffer_DevicesConfiguration-value with {"id":5826}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_TempCCDSetPoint_LimitsConfiguration-value with {"id":5827}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_TempCCD_LimitsConfiguration-value with {"id":5829}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_TempColdPlate_LimitsConfiguration-value with {"id":5828}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_TempCryoHead_LimitsConfiguration-value with {"id":5832}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_Vacuum_LimitsConfiguration-value with {"id":5830}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Analog_I_LimitsConfiguration-value with {"id":5831}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Analog_V_LimitsConfiguration-value with {"id":5833}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Aux_I_LimitsConfiguration-value with {"id":5854}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Aux_V_LimitsConfiguration-value with {"id":5855}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_ClkHigh_I_LimitsConfiguration-value with {"id":5857}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_ClkHigh_V_LimitsConfiguration-value with {"id":5856}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_ClkLow_I_LimitsConfiguration-value with {"id":5858}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_ClkLow_V_LimitsConfiguration-value with {"id":5859}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_DPHI_I_LimitsConfiguration-value with {"id":5861}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_DPHI_V_LimitsConfiguration-value with {"id":5862}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Digital_I_LimitsConfiguration-value with {"id":5860}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Digital_V_LimitsConfiguration-value with {"id":5864}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Fan_I_LimitsConfiguration-value with {"id":5865}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Fan_V_LimitsConfiguration-value with {"id":5863}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_HVBias_I_LimitsConfiguration-value with {"id":5866}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_HVBias_V_LimitsConfiguration-value with {"id":5867}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Hameg1_DevicesConfiguration-value with {"id":5868}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Hameg1_PowerConfiguration-value with {"id":5869}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Hameg2_DevicesConfiguration-value with {"id":5870}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Hameg2_PowerConfiguration-value with {"id":5878}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Hameg3_DevicesConfiguration-value with {"id":5877}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Hameg3_PowerConfiguration-value with {"id":5879}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Keithley_DevicesConfiguration-value with {"id":5880}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_Keithley_PowerConfiguration-value with {"id":5887}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_OD_I_LimitsConfiguration-value with {"id":5882}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_OD_V_LimitsConfiguration-value with {"id":5888}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_OTM_I_LimitsConfiguration-value with {"id":5881}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_OTM_V_LimitsConfiguration-value with {"id":5891}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_PeriodicTasks_GeneralConfiguration-value with {"id":5886}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ats_power_PeriodicTasks_timersConfiguration-value with {"id":5883}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_authList-value with {"id":5890}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_bonn_shutter_Device_DevicesConfiguration-value with {"id":5889}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_bonn_shutter_Device_GeneralConfiguration-value with {"id":5884}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_bonn_shutter_Device_LimitsConfiguration-value with {"id":5885}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_bonn_shutter_GeneralConfiguration-value with {"id":5892}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_bonn_shutter_PeriodicTasks_GeneralConfiguration-value with {"id":5893}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_bonn_shutter_PeriodicTasks_timersConfiguration-value with {"id":5896}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_calibrationDetailedState-value with {"id":5894}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_ccsCommandState-value with {"id":5895}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_configurationApplied-value with {"id":5898}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_configurationsAvailable-value with {"id":5897}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_PeriodicTasks_GeneralConfiguration-value with {"id":5899}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_PeriodicTasks_timersConfiguration-value with {"id":5900}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_Stats_StatisticsConfiguration-value with {"id":5901}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_StoreConfiguration-value with {"id":5902}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_Store_DevicesConfiguration-value with {"id":5903}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_Store_LimitsConfiguration-value with {"id":5929}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_daq_monitor_Store_StoreConfiguration-value with {"id":5944}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_endOfImageTelemetry-value with {"id":5945}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_endReadout-value with {"id":5946}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_endShutterClose-value with {"id":5948}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_endShutterOpen-value with {"id":5947}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_endTakeImage-value with {"id":5949}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_errorCode-value with {"id":5950}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_fileCommandExecution-value with {"id":5952}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_fitsFilesWritten-value with {"id":5954}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focalPlaneSummaryInfo-value with {"id":5959}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Ccd_HardwareIdConfiguration-value with {"id":5955}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Ccd_LimitsConfiguration-value with {"id":5962}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Ccd_RaftsConfiguration-value with {"id":5956}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_ImageDatabaseService_GeneralConfiguration-value with {"id":5951}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_ImageNameService_GeneralConfiguration-value with {"id":5957}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_InstrumentConfig_InstrumentConfiguration-value with {"id":5958}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_PeriodicTasks_GeneralConfiguration-value with {"id":5953}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_PeriodicTasks_timersConfiguration-value with {"id":5961}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Raft_HardwareIdConfiguration-value with {"id":5960}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Raft_RaftTempControlConfiguration-value with {"id":5963}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Raft_RaftTempControlStatusConfiguration-value with {"id":5964}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_RebTotalPower_LimitsConfiguration-value with {"id":5965}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_DevicesConfiguration-value with {"id":5966}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_HardwareIdConfiguration-value with {"id":5967}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_LimitsConfiguration-value with {"id":5969}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_RaftsConfiguration-value with {"id":5968}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_RaftsLimitsConfiguration-value with {"id":5970}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_RaftsPowerConfiguration-value with {"id":5991}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_Reb_timersConfiguration-value with {"id":5994}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_SequencerConfig_DAQConfiguration-value with {"id":5992}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_SequencerConfig_SequencerConfiguration-value with {"id":5993}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_focal_plane_WebHooksConfig_VisualizationConfiguration-value with {"id":5995}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_heartbeat-value with {"id":5998}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_imageReadinessDetailedState-value with {"id":5997}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_imageReadoutParameters-value with {"id":6006}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_imageStored-value with {"id":5996}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_imageVisualization-value with {"id":6005}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_ImageHandler_CommandsConfiguration-value with {"id":6001}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_ImageHandler_DAQConfiguration-value with {"id":5999}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_ImageHandler_FitsHandlingConfiguration-value with {"id":6003}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_PeriodicTasks_GeneralConfiguration-value with {"id":6002}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_PeriodicTasks_timersConfiguration-value with {"id":6000}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_Reb_FitsHandlingConfiguration-value with {"id":6004}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_image_handling_Reb_GeneralConfiguration-value with {"id":6008}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_largeFileObjectAvailable-value with {"id":6009}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_logLevel-value with {"id":6007}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_logMessage-value with {"id":6010}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_notReadyToTakeImage-value with {"id":6011}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_offlineDetailedState-value with {"id":6013}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_prepareToTakeImage-value with {"id":6012}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_raftsDetailedState-value with {"id":6014}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_readyToTakeImage-value with {"id":6015}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_shutterBladeMotionProfile-value with {"id":6016}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_shutterDetailedState-value with {"id":6037}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_shutterMotionProfile-value with {"id":6038}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_simulationMode-value with {"id":6039}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_softwareVersions-value with {"id":6040}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_startIntegration-value with {"id":6042}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_startReadout-value with {"id":6041}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_startShutterClose-value with {"id":6047}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_startShutterOpen-value with {"id":6046}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_summaryState-value with {"id":6048}
# Registered schema under new subject source.lsst.sal.ATCamera.logevent_summaryStatus-value with {"id":6049}
# Registered schema under new subject source.lsst.sal.ATCamera.power-value with {"id":6051}
# Registered schema under new subject source.lsst.sal.ATCamera.vacuum-value with {"id":6052}
# Registered schema under new subject source.lsst.sal.ATDome.ackcmd-value with {"id":6786}
# Registered schema under new subject source.lsst.sal.ATDome.command_closeShutter-value with {"id":6789}
# Registered schema under new subject source.lsst.sal.ATDome.command_disable-value with {"id":6790}
# Registered schema under new subject source.lsst.sal.ATDome.command_enable-value with {"id":6791}
# Registered schema under new subject source.lsst.sal.ATDome.command_exitControl-value with {"id":6792}
# Registered schema under new subject source.lsst.sal.ATDome.command_homeAzimuth-value with {"id":6793}
# Registered schema under new subject source.lsst.sal.ATDome.command_moveAzimuth-value with {"id":6794}
# Registered schema under new subject source.lsst.sal.ATDome.command_moveShutterDropoutDoor-value with {"id":6801}
# Registered schema under new subject source.lsst.sal.ATDome.command_moveShutterMainDoor-value with {"id":6802}
# Registered schema under new subject source.lsst.sal.ATDome.command_openShutter-value with {"id":6805}
# Registered schema under new subject source.lsst.sal.ATDome.command_setAuthList-value with {"id":6804}
# Registered schema under new subject source.lsst.sal.ATDome.command_setLogLevel-value with {"id":6803}
# Registered schema under new subject source.lsst.sal.ATDome.command_standby-value with {"id":6845}
# Registered schema under new subject source.lsst.sal.ATDome.command_start-value with {"id":6846}
# Registered schema under new subject source.lsst.sal.ATDome.command_stopMotion-value with {"id":6848}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_allAxesInPosition-value with {"id":6849}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_authList-value with {"id":6850}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_azimuthCommandedState-value with {"id":6851}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_azimuthInPosition-value with {"id":6958}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_azimuthState-value with {"id":6960}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_configurationApplied-value with {"id":6966}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_configurationsAvailable-value with {"id":6969}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_doorEncoderExtremes-value with {"id":6970}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_dropoutDoorCommandedState-value with {"id":6971}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_dropoutDoorState-value with {"id":6972}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_emergencyStop-value with {"id":6973}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_errorCode-value with {"id":6974}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_heartbeat-value with {"id":6981}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_lastAzimuthGoTo-value with {"id":6982}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_logLevel-value with {"id":6983}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_logMessage-value with {"id":6984}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_mainDoorCommandedState-value with {"id":6985}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_mainDoorState-value with {"id":7011}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_moveCode-value with {"id":7012}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_scbLink-value with {"id":7015}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_settingsAppliedDomeController-value with {"id":7018}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_settingsAppliedDomeTcp-value with {"id":7017}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_shutterInPosition-value with {"id":7019}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_simulationMode-value with {"id":7096}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_softwareVersions-value with {"id":7104}
# Registered schema under new subject source.lsst.sal.ATDome.logevent_summaryState-value with {"id":7110}
# Registered schema under new subject source.lsst.sal.ATDome.position-value with {"id":7111}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.ackcmd-value with {"id":7112}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_disable-value with {"id":7113}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_enable-value with {"id":7114}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_exitControl-value with {"id":7116}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_setAuthList-value with {"id":7117}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_setFollowingMode-value with {"id":7134}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_setLogLevel-value with {"id":7131}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_standby-value with {"id":7130}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.command_start-value with {"id":7132}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_algorithm-value with {"id":7133}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_authList-value with {"id":7148}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_configurationApplied-value with {"id":7149}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_configurationsAvailable-value with {"id":7159}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_errorCode-value with {"id":7160}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_followingMode-value with {"id":7161}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_heartbeat-value with {"id":7162}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_logLevel-value with {"id":7230}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_logMessage-value with {"id":7237}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_simulationMode-value with {"id":7250}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_softwareVersions-value with {"id":7251}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_summaryState-value with {"id":7252}
# Registered schema under new subject source.lsst.sal.ATDomeTrajectory.logevent_telescopeVignetted-value with {"id":7253}
# Registered schema under new subject source.lsst.sal.ATHeaderService.ackcmd-value with {"id":6058}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_disable-value with {"id":6056}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_enable-value with {"id":6057}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_exitControl-value with {"id":6061}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_setAuthList-value with {"id":6062}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_setLogLevel-value with {"id":6063}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_standby-value with {"id":6064}
# Registered schema under new subject source.lsst.sal.ATHeaderService.command_start-value with {"id":6060}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_authList-value with {"id":6065}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_errorCode-value with {"id":6067}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_heartbeat-value with {"id":6066}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_largeFileObjectAvailable-value with {"id":6068}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_logLevel-value with {"id":6070}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_logMessage-value with {"id":6071}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_simulationMode-value with {"id":6073}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_softwareVersions-value with {"id":6069}
# Registered schema under new subject source.lsst.sal.ATHeaderService.logevent_summaryState-value with {"id":6072}
# Registered schema under new subject source.lsst.sal.ATHexapod.ackcmd-value with {"id":7254}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_applyPositionLimits-value with {"id":7256}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_applyPositionOffset-value with {"id":7257}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_disable-value with {"id":7279}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_enable-value with {"id":7281}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_exitControl-value with {"id":7280}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_moveToPosition-value with {"id":7283}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_pivot-value with {"id":7282}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_setAuthList-value with {"id":7288}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_setLogLevel-value with {"id":7292}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_setMaxSystemSpeeds-value with {"id":7294}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_standby-value with {"id":7295}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_start-value with {"id":7296}
# Registered schema under new subject source.lsst.sal.ATHexapod.command_stopAllAxes-value with {"id":7297}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_authList-value with {"id":7350}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_configurationApplied-value with {"id":7353}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_configurationsAvailable-value with {"id":7358}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_detailedState-value with {"id":7359}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_errorCode-value with {"id":7366}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_heartbeat-value with {"id":7367}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_inPosition-value with {"id":7368}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_logLevel-value with {"id":7369}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_logMessage-value with {"id":7370}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_positionUpdate-value with {"id":7385}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_readyForCommand-value with {"id":7386}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_settingsAppliedPivot-value with {"id":7387}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_settingsAppliedPositionLimits-value with {"id":7388}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_settingsAppliedTcp-value with {"id":7389}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_settingsAppliedVelocities-value with {"id":7390}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_simulationMode-value with {"id":7406}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_softwareVersions-value with {"id":7408}
# Registered schema under new subject source.lsst.sal.ATHexapod.logevent_summaryState-value with {"id":7407}
# Registered schema under new subject source.lsst.sal.ATHexapod.positionStatus-value with {"id":7409}
# Registered schema under new subject source.lsst.sal.ATMCS.ackcmd-value with {"id":7814}
# Registered schema under new subject source.lsst.sal.ATMCS.azEl_mountMotorEncoders-value with {"id":7962}
# Registered schema under new subject source.lsst.sal.ATMCS.command_disable-value with {"id":7812}
# Registered schema under new subject source.lsst.sal.ATMCS.command_enable-value with {"id":7813}
# Registered schema under new subject source.lsst.sal.ATMCS.command_exitControl-value with {"id":7834}
# Registered schema under new subject source.lsst.sal.ATMCS.command_setAuthList-value with {"id":7836}
# Registered schema under new subject source.lsst.sal.ATMCS.command_setInstrumentPort-value with {"id":7835}
# Registered schema under new subject source.lsst.sal.ATMCS.command_setLogLevel-value with {"id":7837}
# Registered schema under new subject source.lsst.sal.ATMCS.command_standby-value with {"id":7805}
# Registered schema under new subject source.lsst.sal.ATMCS.command_start-value with {"id":7839}
# Registered schema under new subject source.lsst.sal.ATMCS.command_startTracking-value with {"id":7840}
# Registered schema under new subject source.lsst.sal.ATMCS.command_stopTracking-value with {"id":7842}
# Registered schema under new subject source.lsst.sal.ATMCS.command_trackTarget-value with {"id":7843}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_allAxesInPosition-value with {"id":7841}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_atMountState-value with {"id":7846}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_authList-value with {"id":7847}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthBrake1-value with {"id":7844}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthBrake2-value with {"id":7845}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthDrive1Status-value with {"id":7848}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthDrive2Status-value with {"id":7849}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthInPosition-value with {"id":7851}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthLimitSwitchCCW-value with {"id":7850}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthLimitSwitchCW-value with {"id":7852}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthToppleBlockCCW-value with {"id":7853}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_azimuthToppleBlockCW-value with {"id":7854}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_detailedState-value with {"id":7890}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_elevationBrake-value with {"id":7892}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_elevationDriveStatus-value with {"id":7891}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_elevationInPosition-value with {"id":7893}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_elevationLimitSwitchLower-value with {"id":7898}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_elevationLimitSwitchUpper-value with {"id":7894}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_errorCode-value with {"id":7896}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_heartbeat-value with {"id":7900}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_logLevel-value with {"id":7897}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_logMessage-value with {"id":7908}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3DriveStatus-value with {"id":7895}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3InPosition-value with {"id":7907}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3PortSelected-value with {"id":7906}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3RotatorDetentSwitches-value with {"id":7902}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3RotatorLimitSwitchCCW-value with {"id":7903}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3RotatorLimitSwitchCW-value with {"id":7909}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_m3State-value with {"id":7901}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth1Brake-value with {"id":7904}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth1DriveStatus-value with {"id":7905}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth1LimitSwitchCCW-value with {"id":7899}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth1LimitSwitchCW-value with {"id":7910}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth1RotatorInPosition-value with {"id":7916}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth2Brake-value with {"id":7932}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth2DriveStatus-value with {"id":7934}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth2LimitSwitchCCW-value with {"id":7933}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth2LimitSwitchCW-value with {"id":7955}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_nasmyth2RotatorInPosition-value with {"id":7956}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_positionLimits-value with {"id":7958}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_simulationMode-value with {"id":7957}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_softwareVersions-value with {"id":7959}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_summaryState-value with {"id":7961}
# Registered schema under new subject source.lsst.sal.ATMCS.logevent_target-value with {"id":7960}
# Registered schema under new subject source.lsst.sal.ATMCS.measuredMotorVelocity-value with {"id":7965}
# Registered schema under new subject source.lsst.sal.ATMCS.measuredTorque-value with {"id":7968}
# Registered schema under new subject source.lsst.sal.ATMCS.mount_AzEl_Encoders-value with {"id":7967}
# Registered schema under new subject source.lsst.sal.ATMCS.mount_Nasmyth_Encoders-value with {"id":7963}
# Registered schema under new subject source.lsst.sal.ATMCS.nasymth_m3_mountMotorEncoders-value with {"id":7964}
# Registered schema under new subject source.lsst.sal.ATMCS.torqueDemand-value with {"id":7966}
# Registered schema under new subject source.lsst.sal.ATMCS.trajectory-value with {"id":7969}
# Registered schema under new subject source.lsst.sal.ATMonochromator.ackcmd-value with {"id":6559}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_calibrateWavelength-value with {"id":6562}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_changeSlitWidth-value with {"id":6571}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_changeWavelength-value with {"id":6563}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_disable-value with {"id":6566}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_enable-value with {"id":6572}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_exitControl-value with {"id":6568}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_power-value with {"id":6570}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_selectGrating-value with {"id":6565}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_setAuthList-value with {"id":6567}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_setLogLevel-value with {"id":6560}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_standby-value with {"id":6569}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_start-value with {"id":6573}
# Registered schema under new subject source.lsst.sal.ATMonochromator.command_updateMonochromatorSetup-value with {"id":6564}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_authList-value with {"id":6561}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_configurationApplied-value with {"id":6574}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_configurationsAvailable-value with {"id":6578}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_detailedState-value with {"id":6577}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_entrySlitWidth-value with {"id":6575}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_errorCode-value with {"id":6576}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_exitSlitWidth-value with {"id":6734}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_heartbeat-value with {"id":6735}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_inPosition-value with {"id":6736}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_internalCommand-value with {"id":6741}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_largeFileObjectAvailable-value with {"id":6742}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_logLevel-value with {"id":6743}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_logMessage-value with {"id":6744}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_loopTimeOutOfRange-value with {"id":6745}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_monochromatorConnected-value with {"id":6746}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_rejectedCommand-value with {"id":6747}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_selectedGrating-value with {"id":6748}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_settingsAppliedLoop-value with {"id":6749}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_settingsAppliedMonoCommunication-value with {"id":6751}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_settingsAppliedMonoHeartbeat-value with {"id":6750}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_settingsAppliedMonochromatorRanges-value with {"id":6756}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_simulationMode-value with {"id":6759}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_slitWidth-value with {"id":6762}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_softwareVersions-value with {"id":6760}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_status-value with {"id":6761}
# Registered schema under new subject source.lsst.sal.ATMonochromator.logevent_summaryState-value with {"id":6763}
# ...
# Registered schema under new subject source.lsst.sal.ScriptQueue.command_showQueue-value with {"id":6533}
# Registered schema under new subject source.lsst.sal.ScriptQueue.command_showSchema-value with {"id":6535}
# Registered schema under new subject source.lsst.sal.ScriptQueue.command_showScript-value with {"id":6536}
# Registered schema under new subject source.lsst.sal.ScriptQueue.command_standby-value with {"id":6537}
# Registered schema under new subject source.lsst.sal.ScriptQueue.command_start-value with {"id":6538}
# Registered schema under new subject source.lsst.sal.ScriptQueue.command_stopScripts-value with {"id":6539}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_authList-value with {"id":6540}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_availableScripts-value with {"id":6541}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_configSchema-value with {"id":6545}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_errorCode-value with {"id":6546}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_heartbeat-value with {"id":6547}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_logLevel-value with {"id":6552}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_logMessage-value with {"id":6580}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_nextVisit-value with {"id":6582}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_nextVisitCanceled-value with {"id":6581}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_queue-value with {"id":6579}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_rootDirectories-value with {"id":6592}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_script-value with {"id":6593}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_simulationMode-value with {"id":6672}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_softwareVersions-value with {"id":6671}
# Registered schema under new subject source.lsst.sal.ScriptQueue.logevent_summaryState-value with {"id":6683}
# Registered schema under new subject source.lsst.sal.Test.ackcmd-value with {"id":5841}
# Registered schema under new subject source.lsst.sal.Test.arrays-value with {"id":5875}
# Registered schema under new subject source.lsst.sal.Test.command_disable-value with {"id":5835}
# Registered schema under new subject source.lsst.sal.Test.command_enable-value with {"id":5836}
# Registered schema under new subject source.lsst.sal.Test.command_exitControl-value with {"id":5834}
# Registered schema under new subject source.lsst.sal.Test.command_fault-value with {"id":5837}
# Registered schema under new subject source.lsst.sal.Test.command_setArrays-value with {"id":5843}
# Registered schema under new subject source.lsst.sal.Test.command_setAuthList-value with {"id":5839}
# Registered schema under new subject source.lsst.sal.Test.command_setLogLevel-value with {"id":5849}
# Registered schema under new subject source.lsst.sal.Test.command_setScalars-value with {"id":5842}
# Registered schema under new subject source.lsst.sal.Test.command_standby-value with {"id":5853}
# Registered schema under new subject source.lsst.sal.Test.command_start-value with {"id":5840}
# Registered schema under new subject source.lsst.sal.Test.command_wait-value with {"id":5850}
# Registered schema under new subject source.lsst.sal.Test.logevent_arrays-value with {"id":5844}
# Registered schema under new subject source.lsst.sal.Test.logevent_authList-value with {"id":5838}
# Registered schema under new subject source.lsst.sal.Test.logevent_configurationApplied-value with {"id":5848}
# Registered schema under new subject source.lsst.sal.Test.logevent_configurationsAvailable-value with {"id":5846}
# Registered schema under new subject source.lsst.sal.Test.logevent_errorCode-value with {"id":5847}
# Registered schema under new subject source.lsst.sal.Test.logevent_heartbeat-value with {"id":5845}
# Registered schema under new subject source.lsst.sal.Test.logevent_logLevel-value with {"id":5851}
# Registered schema under new subject source.lsst.sal.Test.logevent_logMessage-value with {"id":5852}
# Registered schema under new subject source.lsst.sal.Test.logevent_scalars-value with {"id":5871}
# Registered schema under new subject source.lsst.sal.Test.logevent_simulationMode-value with {"id":5872}
# Registered schema under new subject source.lsst.sal.Test.logevent_softwareVersions-value with {"id":5873}
# Registered schema under new subject source.lsst.sal.Test.logevent_summaryState-value with {"id":5874}
# Registered schema under new subject source.lsst.sal.Test.scalars-value with {"id":5876}
# Registered schema under new subject source.lsst.sal.TunableLaser.ackcmd-value with {"id":7689}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_changeWavelength-value with {"id":7688}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_clearLaserFault-value with {"id":7687}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_disable-value with {"id":7691}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_enable-value with {"id":7690}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_exitControl-value with {"id":7693}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_setAuthList-value with {"id":7694}
# Schema already registered under source.lsst.sal.TunableLaser.command_setBurstCount-value.
# Registered schema under new subject source.lsst.sal.TunableLaser.command_setBurstMode-value with {"id":7695}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_setContinuousMode-value with {"id":7696}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_setLogLevel-value with {"id":7712}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_standby-value with {"id":7713}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_start-value with {"id":7714}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_startPropagateLaser-value with {"id":7716}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_stopPropagateLaser-value with {"id":7715}
# Registered schema under new subject source.lsst.sal.TunableLaser.command_triggerBurst-value with {"id":7717}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_authList-value with {"id":7718}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_burstCountSet-value with {"id":7734}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_burstModeSet-value with {"id":7746}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_configurationApplied-value with {"id":7737}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_configurationsAvailable-value with {"id":7742}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_continuousModeSet-value with {"id":7735}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_detailedState-value with {"id":7740}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_errorCode-value with {"id":7739}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_heartbeat-value with {"id":7745}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_laserInstabilityFlag-value with {"id":7736}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_logLevel-value with {"id":7738}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_logMessage-value with {"id":7741}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_simulationMode-value with {"id":7743}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_softwareVersions-value with {"id":7744}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_summaryState-value with {"id":7780}
# Registered schema under new subject source.lsst.sal.TunableLaser.logevent_wavelengthChanged-value with {"id":7781}
# Registered schema under new subject source.lsst.sal.TunableLaser.temperature-value with {"id":7779}
# Registered schema under new subject source.lsst.sal.TunableLaser.wavelength-value with {"id":7782}
# Registered schema under new subject source.lsst.sal.Watcher.ackcmd-value with {"id":6695}
# Registered schema under new subject source.lsst.sal.Watcher.command_acknowledge-value with {"id":6696}
# Registered schema under new subject source.lsst.sal.Watcher.command_disable-value with {"id":6697}
# Registered schema under new subject source.lsst.sal.Watcher.command_enable-value with {"id":6698}
# Registered schema under new subject source.lsst.sal.Watcher.command_exitControl-value with {"id":6699}
# Registered schema under new subject source.lsst.sal.Watcher.command_mute-value with {"id":6700}
# Registered schema under new subject source.lsst.sal.Watcher.command_setAuthList-value with {"id":6701}
# Registered schema under new subject source.lsst.sal.Watcher.command_setLogLevel-value with {"id":6705}
# Registered schema under new subject source.lsst.sal.Watcher.command_showAlarms-value with {"id":6706}
# Registered schema under new subject source.lsst.sal.Watcher.command_standby-value with {"id":6707}
# Registered schema under new subject source.lsst.sal.Watcher.command_start-value with {"id":6740}
# Registered schema under new subject source.lsst.sal.Watcher.command_unacknowledge-value with {"id":6752}
# Registered schema under new subject source.lsst.sal.Watcher.command_unmute-value with {"id":6753}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_alarm-value with {"id":6754}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_authList-value with {"id":6755}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_configurationApplied-value with {"id":6757}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_configurationsAvailable-value with {"id":6758}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_errorCode-value with {"id":6853}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_heartbeat-value with {"id":6854}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_logLevel-value with {"id":6864}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_logMessage-value with {"id":6868}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_notification-value with {"id":6869}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_simulationMode-value with {"id":6878}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_softwareVersions-value with {"id":6879}
# Registered schema under new subject source.lsst.sal.Watcher.logevent_summaryState-value with {"id":6880}
# Registered schema under new subject source.lsst.sal.WeatherForecast.ackcmd-value with {"id":6859}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_disable-value with {"id":6861}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_enable-value with {"id":6862}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_exitControl-value with {"id":6863}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_setAuthList-value with {"id":6865}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_setLogLevel-value with {"id":6866}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_standby-value with {"id":6867}
# Registered schema under new subject source.lsst.sal.WeatherForecast.command_start-value with {"id":6870}
# Registered schema under new subject source.lsst.sal.WeatherForecast.dailyTrend-value with {"id":7020}
# Registered schema under new subject source.lsst.sal.WeatherForecast.hourlyTrend-value with {"id":7021}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_authList-value with {"id":6874}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_configurationApplied-value with {"id":6871}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_configurationsAvailable-value with {"id":6875}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_errorCode-value with {"id":6872}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_heartbeat-value with {"id":6876}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_logLevel-value with {"id":6873}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_logMessage-value with {"id":6877}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_simulationMode-value with {"id":6930}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_softwareVersions-value with {"id":6929}
# Registered schema under new subject source.lsst.sal.WeatherForecast.logevent_summaryState-value with {"id":6928}
# Registered schema under new subject source.lsst.sal.WeatherForecast.metadata-value with {"id":7025}
# Schema already registered under source.lsst.sal.WeatherStation.ackcmd-value.
# Schema already registered under source.lsst.sal.WeatherStation.airPressure-value.
# Schema already registered under source.lsst.sal.WeatherStation.airTemperature-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_disable-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_enable-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_exitControl-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_setAuthList-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_setLogLevel-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_standby-value.
# Schema already registered under source.lsst.sal.WeatherStation.command_start-value.
# Schema already registered under source.lsst.sal.WeatherStation.dewPoint-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_authList-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_configurationApplied-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_configurationsAvailable-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_errorCode-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_heartbeat-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_logLevel-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_logMessage-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_simulationMode-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_softwareVersions-value.
# Schema already registered under source.lsst.sal.WeatherStation.logevent_summaryState-value.
# Schema already registered under source.lsst.sal.WeatherStation.precipitation-value.
# Schema already registered under source.lsst.sal.WeatherStation.relativeHumidity-value.
# Schema already registered under source.lsst.sal.WeatherStation.snowDepth-value.
# Schema already registered under source.lsst.sal.WeatherStation.soilTemperature-value.
# Schema already registered under source.lsst.sal.WeatherStation.solarNetRadiation-value.
# Schema already registered under source.lsst.sal.WeatherStation.weather-value.
# Schema already registered under source.lsst.sal.WeatherStation.windDirection-value.
# Schema already registered under source.lsst.sal.WeatherStation.windGustDirection-value.
# Schema already registered under source.lsst.sal.WeatherStation.windSpeed-value.
